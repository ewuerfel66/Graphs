# %%
from social import SocialGraph

# %%
sg = SocialGraph()

# %%
sg.populate_graph(100, 1)

# %%
sg.friendships
# Out:
# {1: {46, 60, 88},
#  2: {87},
#  3: {32},
#  4: {50, 52},
#  5: {33, 43},
#  6: {36, 64},
#  7: {83},
#  8: {14, 58, 72},
#  9: {34, 47},
#  10: {38, 43, 84},
#  11: {16, 56, 75},
#  12: {14, 28, 77},
#  13: {76, 98},
#  14: {8, 12, 38},
#  15: {32, 62, 89},
#  16: {11, 69},
#  17: {35, 86},
#  18: {31, 74},
#  19: {61},
#  20: {93},
#  21: {75},
#  22: {56},
#  23: {45},
#  24: {97, 99},
#  25: {82},
#  26: {70},
#  27: {40},
#  28: {12, 44},
#  29: {54, 70},
#  30: {63, 83},
#  31: {18},
#  32: {3, 15},
#  33: {5, 57},
#  34: {9, 40, 55},
#  35: {17, 80, 85, 92},
#  36: {6, 62},
#  37: {57, 61, 77},
#  38: {10, 14, 65},
#  39: {46},
#  40: {27, 34},
#  41: {42},
#  42: {41, 55, 66},
#  43: {5, 10},
#  44: {28},
#  45: {23, 90, 94},
#  46: {1, 39, 96},
#  47: {9},
#  48: {73},
#  49: {53},
#  50: {4},
#  51: {87},
#  52: {4, 56},
#  53: {49, 73, 74},
#  54: {29, 80},
#  55: {34, 42, 60},
#  56: {11, 22, 52},
#  57: {33, 37},
#  58: {8},
#  59: {67, 69, 97},
#  60: {1, 55, 76},
# ...

# %%
sg.get_all_social_paths(1)
# Out:
# {1: [1],
#  88: [1, 88],
#  60: [1, 60],
#  46: [1, 46],
#  76: [1, 60, 76],
#  55: [1, 60, 55],
#  96: [1, 46, 96],
#  39: [1, 46, 39],
#  13: [1, 60, 76, 13],
#  34: [1, 60, 55, 34],
#  42: [1, 60, 55, 42],
#  98: [1, 60, 76, 13, 98],
#  40: [1, 60, 55, 34, 40],
#  9: [1, 60, 55, 34, 9],
#  41: [1, 60, 55, 42, 41],
#  66: [1, 60, 55, 42, 66],
#  68: [1, 60, 76, 13, 98, 68],
#  27: [1, 60, 55, 34, 40, 27],
#  47: [1, 60, 55, 34, 9, 47],
#  67: [1, 60, 55, 42, 66, 67],
#  91: [1, 60, 76, 13, 98, 68, 91],
#  63: [1, 60, 76, 13, 98, 68, 63],
#  59: [1, 60, 55, 42, 66, 67, 59],
#  73: [1, 60, 76, 13, 98, 68, 91, 73],
#  93: [1, 60, 76, 13, 98, 68, 91, 93],
#  62: [1, 60, 76, 13, 98, 68, 63, 62],
#  30: [1, 60, 76, 13, 98, 68, 63, 30],
#  87: [1, 60, 76, 13, 98, 68, 63, 87],
#  97: [1, 60, 55, 42, 66, 67, 59, 97],
#  69: [1, 60, 55, 42, 66, 67, 59, 69],
#  48: [1, 60, 76, 13, 98, 68, 91, 73, 48],
#  53: [1, 60, 76, 13, 98, 68, 91, 73, 53],
#  20: [1, 60, 76, 13, 98, 68, 91, 93, 20],
# ...

# %%
num_users = 10
avg_friendships = 2

# %%
friend_count = [avg_friendships for i in range(num_users)]

# %%
friend_count
# Out:
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
for friend in sg.friendships[1]:
    print(friend)
# Out:
# 88
# 60
# 46
